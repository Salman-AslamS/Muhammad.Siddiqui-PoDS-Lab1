# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
passenger_data = pd.read_csv('Desktop/Muhammad.Siddiqui-PoDS-Labs/Lab 2/passengerData.csv')
ticket_prices = pd.read_excel('/Users/sameenrasheedi/Desktop/Muhammad.Siddiqui-PoDS-Labs/Lab 2/ticketPrices.xlsx')
#tp = ticket_prices.to_csv()

# %%
print(passenger_data.head(3))
passenger_data.info()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  TicketType
# 0                            Braund, Mr. Owen Harris    male  22.0           1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0           2
# 2                             Heikkinen, Miss. Laina  female  26.0           3
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   TicketType   891 non-null    int64
# ...

# %%
print(ticket_prices)
#df_tp= pd.DataFrame(tp)
# Out:
#    TicketType  Fare
# 0           1    33
# 1           2    56
# 2           3    77
# 3           4    22
# 4           5    14
# 5           6    66
# 6           7    87
# 7           8    36

# %%
data = pd.merge(passenger_data, ticket_prices, on='TicketType', how='outer')
data_1 = data.dropna(axis='rows')
#data_1.info()

data_1.sort_values('Age', ascending=True)
#data.head()
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 436          804         1       3       Thomas, Master. Assad Alexander
# 430          756         1       2             Hamalainen, Master. Viljo
# 616          470         1       3         Baclini, Miss. Helene Barbara
# 527          645         1       3                Baclini, Miss. Eugenie
# 678           79         1       2         Caldwell, Master. Alden Gates
# ..           ...       ...     ...                                   ...
# 461          117         0       3                  Connors, Mr. Patrick
# 12            97         0       1             Goldschmidt, Mr. George B
# 619          494         0       1               Artagaveytia, Mr. Ramon
# 442          852         0       3                   Svensson, Mr. Johan
# 747          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#         Sex    Age  TicketType  Fare
# 436    male   0.42           4    22
# ...

# %%
data_1['Name'][data_1['Age'] == data_1['Age'].max()]
# Out:
# 747    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %%
plt.scatter(data=data_1, x='Age', y='Fare')
plt.ylabel('Ticket Prices')
plt.xlabel('Age')
plt.show()

# %%
data_2 = data_1.groupby('Sex')
data_f = data_2.get_group('female')
data_f
# Out:
#      PassengerId  Survived  Pclass  \
# 1              9         1       3
# 3             25         0       3
# 5             41         0       3
# 7             57         1       2
# 11            89         1       1
# ..           ...       ...     ...
# 882          824         1       3
# 886          856         1       3
# 888          872         1       1
# 889          880         1       1
# 890          888         1       1
#
#                                                   Name     Sex   Age  \
# 1    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 3                        Palsson, Miss. Torborg Danira  female   8.0
# 5       Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0
# 7                                    Rugg, Miss. Emily  female  21.0
# 11                          Fortune, Miss. Mabel Helen  female  23.0
# ..                                                 ...     ...   ...
# ...

# %%
data_sorted = data_f[(data_f['Age'] >= 40) & (data_f['Age'] <= 50) & (data_f['Fare'] >= 40)]

# %%
plt.scatter(data=data_sorted, x='Age', y='Fare')
plt.ylabel('Ticket Prices')
plt.xlabel('Age')
plt.show()

# %%
t_s = pd.read_csv('/Users/sameenrasheedi/Desktop/Muhammad.Siddiqui-PoDS-Labs/Lab 2/titanicSurvival_m.csv')
t_s
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
t_s.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare            46
# Cabin          687
# Embarked         2
# dtype: int64

# %%
t_s.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  845.000000
# mean     0.381594   32.304319
# std      0.806057   49.792612
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.275000
# max      6.000000  512.329200

# %%
t_s.fillna(0)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
plt.scatter(data=t_s, x='Age', y='Fare')
plt.ylabel('Ticket Prices')
plt.xlabel('Age')
plt.show()

# %%
a = t_s['Age'].mean()
print(a)
b = t_s['Fare'].mean()
print(b)
t_s['Age'].fillna(a, inplace=True)
t_s['Fare'].fillna(b, inplace=True)
t_s
# Out:
# 29.69911764705882
# 32.30431881656804
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ...

# %%
plt.scatter(data=t_s, x='Age', y='Fare')
plt.ylabel('Ticket Prices')
plt.xlabel('Age')
plt.show()

# %%
# NaN = 0
# The difference is not much seen rather the density of points is high in the lower region. The NaN = mean seems
# a much realistic plot and closer to realtime plot as their can notn be passengers with age that is zero and fare that is zero

# %%
tb = pd.read_csv('/Users/sameenrasheedi/Desktop/Muhammad.Siddiqui-PoDS-Labs/Lab 2/TB_burden_countries_2014-09-29.csv')
tb
# Out:
#           country iso2 iso3  iso_numeric g_whoregion  year  e_pop_num  \
# 0     Afghanistan   AF  AFG            4         EMR  1990   11731193
# 1     Afghanistan   AF  AFG            4         EMR  1991   12612043
# 2     Afghanistan   AF  AFG            4         EMR  1992   13811876
# 3     Afghanistan   AF  AFG            4         EMR  1993   15175325
# 4     Afghanistan   AF  AFG            4         EMR  1994   16485018
# ...           ...  ...  ...          ...         ...   ...        ...
# 4898     Zimbabwe   ZW  ZWE          716         AFR  2008   12784041
# 4899     Zimbabwe   ZW  ZWE          716         AFR  2009   12888918
# 4900     Zimbabwe   ZW  ZWE          716         AFR  2010   13076978
# 4901     Zimbabwe   ZW  ZWE          716         AFR  2011   13358738
# 4902     Zimbabwe   ZW  ZWE          716         AFR  2012   13724317
#
#       e_prev_100k  e_prev_100k_lo  e_prev_100k_hi  ...  e_inc_tbhiv_100k  \
# ...

# %%
tb.isna().sum()
# Out:
# country                        0
# iso2                          23
# iso3                           0
# iso_numeric                    0
# g_whoregion                    0
# year                           0
# e_pop_num                      0
# e_prev_100k                   11
# e_prev_100k_lo                11
# e_prev_100k_hi                11
# e_prev_num                    11
# e_prev_num_lo                 11
# e_prev_num_hi                 11
# e_mort_exc_tbhiv_100k          1
# e_mort_exc_tbhiv_100k_lo       1
# e_mort_exc_tbhiv_100k_hi       1
# e_mort_exc_tbhiv_num           1
# e_mort_exc_tbhiv_num_lo        1
# e_mort_exc_tbhiv_num_hi        1
# source_mort                    1
# e_inc_100k                     1
# e_inc_100k_lo                  1
# e_inc_100k_hi                  1
# e_inc_num                      1
# e_inc_num_lo                   1
# e_inc_num_hi                   1
# e_tbhiv_prct                1250
# e_tbhiv_prct_lo             1446
# ...

# %%
#tb.fillna(data.mean)

# Step 1: Identify numeric columns
numeric_columns = tb.select_dtypes(include=['number']).columns

# Step 2: Calculate the mean for each numeric column
column_means = tb[numeric_columns].mean()

# Step 3: Replace NaN values in numeric columns with their respective means
tb[numeric_columns] = tb[numeric_columns].fillna(column_means)

# Resulting DataFrame
tb
tb.isna().sum()
# Out:
# country                      0
# iso2                        23
# iso3                         0
# iso_numeric                  0
# g_whoregion                  0
# year                         0
# e_pop_num                    0
# e_prev_100k                  0
# e_prev_100k_lo               0
# e_prev_100k_hi               0
# e_prev_num                   0
# e_prev_num_lo                0
# e_prev_num_hi                0
# e_mort_exc_tbhiv_100k        0
# e_mort_exc_tbhiv_100k_lo     0
# e_mort_exc_tbhiv_100k_hi     0
# e_mort_exc_tbhiv_num         0
# e_mort_exc_tbhiv_num_lo      0
# e_mort_exc_tbhiv_num_hi      0
# source_mort                  1
# e_inc_100k                   0
# e_inc_100k_lo                0
# e_inc_100k_hi                0
# e_inc_num                    0
# e_inc_num_lo                 0
# e_inc_num_hi                 0
# e_tbhiv_prct                 0
# e_tbhiv_prct_lo              0
# e_tbhiv_prct_hi              0
# e_inc_tbhiv_100k             0
# ...

# %%
plt.hist(data=tb, x='country', orientation='horizontal')
plt.show()

# %%
plt.hist(data=tb, x='e_prev_100k', bins=100)
plt.show()

# %%
plt.hist(data=tb, x='e_inc_num_lo', bins=100)
plt.show()

# %%
plt.hist(data=tb, x='g_whoregion', bins=100)
plt.show()

# %%
plt.hist(data=tb, x='c_cdr_hi', bins=100)
plt.show()

# %%
plt.hist(data=tb, x='e_inc_tbhiv_100k', bins=100)
plt.show()

# %%
#tbu = np.log(tb['e_prev_100k'])
#tbu
#plt.hist(data=tbu, x='e_prev_100k')
#plt.show()

tb['new_e_prev_100k'] = tb['e_prev_100k'].transform(np.log)
tb
# Out:
#           country iso2 iso3  iso_numeric g_whoregion  year  e_pop_num  \
# 0     Afghanistan   AF  AFG            4         EMR  1990   11731193
# 1     Afghanistan   AF  AFG            4         EMR  1991   12612043
# 2     Afghanistan   AF  AFG            4         EMR  1992   13811876
# 3     Afghanistan   AF  AFG            4         EMR  1993   15175325
# 4     Afghanistan   AF  AFG            4         EMR  1994   16485018
# ...           ...  ...  ...          ...         ...   ...        ...
# 4898     Zimbabwe   ZW  ZWE          716         AFR  2008   12784041
# 4899     Zimbabwe   ZW  ZWE          716         AFR  2009   12888918
# 4900     Zimbabwe   ZW  ZWE          716         AFR  2010   13076978
# 4901     Zimbabwe   ZW  ZWE          716         AFR  2011   13358738
# 4902     Zimbabwe   ZW  ZWE          716         AFR  2012   13724317
#
#       e_prev_100k  e_prev_100k_lo  e_prev_100k_hi  ...  e_inc_tbhiv_100k_hi  \
# ...

# %%
plt.hist(data=tb, x='new_e_prev_100k', bins=100)
plt.show()

# %%
# Define a function to perform min-max scaling on a column
def min_max_scaling(column):
    min_val = column.min()
    max_val = column.max()
    return (column - min_val) / (max_val - min_val)

tb[numeric_columns] = tb[numeric_columns].apply(min_max_scaling)
tb
# Out:
#           country iso2 iso3  iso_numeric g_whoregion      year  e_pop_num  \
# 0     Afghanistan   AF  AFG          0.0         EMR  0.000000   0.008518
# 1     Afghanistan   AF  AFG          0.0         EMR  0.045455   0.009158
# 2     Afghanistan   AF  AFG          0.0         EMR  0.090909   0.010029
# 3     Afghanistan   AF  AFG          0.0         EMR  0.136364   0.011019
# 4     Afghanistan   AF  AFG          0.0         EMR  0.181818   0.011970
# ...           ...  ...  ...          ...         ...       ...        ...
# 4898     Zimbabwe   ZW  ZWE          0.8         AFR  0.818182   0.009283
# 4899     Zimbabwe   ZW  ZWE          0.8         AFR  0.863636   0.009359
# 4900     Zimbabwe   ZW  ZWE          0.8         AFR  0.909091   0.009495
# 4901     Zimbabwe   ZW  ZWE          0.8         AFR  0.954545   0.009700
# 4902     Zimbabwe   ZW  ZWE          0.8         AFR  1.000000   0.009966
#
#       e_prev_100k  e_prev_100k_lo  e_prev_100k_hi  ...  e_inc_tbhiv_100k_hi  \
# ...
